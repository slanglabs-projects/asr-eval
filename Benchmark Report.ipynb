# %% [markdown]
# # Benchmark report

# %% [markdown]
# ## Raw Google Speech vs Raw Indic Confromer

# %%
import pandas as pd

pd.set_option('display.max_rows', 500)

df = pd.read_csv('ASR_quality_metrics_raw.csv')

df
# Out:
#                                 File_name  \
# 0    ff4787fa-59ab-4fa6-8d28-5fcccb05120c
# 1    feec7e5a-fcf6-4850-8614-1c41b8e515db
# 2    fe270614-16d4-416b-855a-5e6e542ad540
# 3    fe1f1315-af02-4483-b280-cbe620051311
# 4    fe1b58c3-8e41-457b-ad0e-12c976e36917
# 5    fdf06a9e-e1fc-42a7-9f8b-83b7729a3314
# 6    fd04afb3-3465-47dc-8c4a-85c5532fb5d3
# 7    fc65298a-237d-4555-8cd8-9c70eb0ac36a
# 8    fbf2fa64-8512-4aee-9c28-dcda27429ffb
# 9    fb4fe4a5-2311-4d60-a01c-d873bbcbae68
# 10   fb0c9ad8-af0a-4ab8-9dce-0ae15e09c786
# 11   fa61899b-052a-4b53-b7d4-e3ff6a290dab
# 12   fa6a612b-8f2e-4d9e-9794-270495811ae0
# 13   f86854f2-8304-470a-b267-cc9b0db7b917
# 14   f9897d8e-4013-404b-8aa4-01939bbe6ed2
# 15   f04865c8-4312-4c5f-9319-01c3a372313f
# 16   f3628df0-447b-4623-bcd5-64aefc185694
# 17   f236a752-3de0-41b6-93be-58122496ced0
# 18   f92e6155-cead-4e42-8a01-fdcb5c681281
# 19   f50b5353-4fb2-4c59-83b4-f4957c2ee83e
# 20   f042fdf7-ad3e-4f99-b3d4-1cf8c65a68ab
# ...

# %% [markdown]
# ### WER Comparison

# %%
print ('Avg WER Comparision')
print(f'Indic_conformer WER: {df["indic_conformer_wer"].mean()}')
print(f'Google Speech WER: {df["google_speech_wer"].mean()}')
# Out:
# Avg WER Comparision
# Indic_conformer WER: 0.2873431448769446
# Google Speech WER: 0.4489248231672923

# %% [markdown]
# ## Raw Google Speech + NeMo vs Raw Indic Confromer + NeMo

# %%
df = pd.read_csv('ASR_quality_metrics_nemo.csv')

df
# Out:
#                                 File_name  \
# 0    ff4787fa-59ab-4fa6-8d28-5fcccb05120c
# 1    feec7e5a-fcf6-4850-8614-1c41b8e515db
# 2    fe270614-16d4-416b-855a-5e6e542ad540
# 3    fe1f1315-af02-4483-b280-cbe620051311
# 4    fe1b58c3-8e41-457b-ad0e-12c976e36917
# 5    fdf06a9e-e1fc-42a7-9f8b-83b7729a3314
# 6    fd04afb3-3465-47dc-8c4a-85c5532fb5d3
# 7    fc65298a-237d-4555-8cd8-9c70eb0ac36a
# 8    fbf2fa64-8512-4aee-9c28-dcda27429ffb
# 9    fb4fe4a5-2311-4d60-a01c-d873bbcbae68
# 10   fb0c9ad8-af0a-4ab8-9dce-0ae15e09c786
# 11   fa61899b-052a-4b53-b7d4-e3ff6a290dab
# 12   fa6a612b-8f2e-4d9e-9794-270495811ae0
# 13   f86854f2-8304-470a-b267-cc9b0db7b917
# 14   f9897d8e-4013-404b-8aa4-01939bbe6ed2
# 15   f04865c8-4312-4c5f-9319-01c3a372313f
# 16   f3628df0-447b-4623-bcd5-64aefc185694
# 17   f236a752-3de0-41b6-93be-58122496ced0
# 18   f92e6155-cead-4e42-8a01-fdcb5c681281
# 19   f50b5353-4fb2-4c59-83b4-f4957c2ee83e
# 20   f042fdf7-ad3e-4f99-b3d4-1cf8c65a68ab
# ...

# %% [markdown]
# ### WER Comparison

# %%
print ('Avg WER Comparision')
print(f'Indic_conformer WER: {df["nemo_indic_conformer_wer"].mean()}')
print(f'Google Speech WER: {df["nemo_google_speech_wer"].mean()}')
# Out:
# Avg WER Comparision
# Indic_conformer WER: 0.3477632355389708
# Google Speech WER: 0.4476100844785617

# %% [markdown]
# ## Raw Google Speech + NeMo + Parser vs Raw Indic Confromer + NeMo + Parser

# %%
df = pd.read_csv('ASR_quality_metrics_slang.csv')

df
# Out:
#                                 File_name  \
# 0    ff4787fa-59ab-4fa6-8d28-5fcccb05120c
# 1    feec7e5a-fcf6-4850-8614-1c41b8e515db
# 2    fe270614-16d4-416b-855a-5e6e542ad540
# 3    fe1f1315-af02-4483-b280-cbe620051311
# 4    fe1b58c3-8e41-457b-ad0e-12c976e36917
# 5    fdf06a9e-e1fc-42a7-9f8b-83b7729a3314
# 6    fd04afb3-3465-47dc-8c4a-85c5532fb5d3
# 7    fc65298a-237d-4555-8cd8-9c70eb0ac36a
# 8    fbf2fa64-8512-4aee-9c28-dcda27429ffb
# 9    fb4fe4a5-2311-4d60-a01c-d873bbcbae68
# 10   fb0c9ad8-af0a-4ab8-9dce-0ae15e09c786
# 11   fa61899b-052a-4b53-b7d4-e3ff6a290dab
# 12   fa6a612b-8f2e-4d9e-9794-270495811ae0
# 13   f86854f2-8304-470a-b267-cc9b0db7b917
# 14   f9897d8e-4013-404b-8aa4-01939bbe6ed2
# 15   f04865c8-4312-4c5f-9319-01c3a372313f
# 16   f3628df0-447b-4623-bcd5-64aefc185694
# 17   f236a752-3de0-41b6-93be-58122496ced0
# 18   f92e6155-cead-4e42-8a01-fdcb5c681281
# 19   f50b5353-4fb2-4c59-83b4-f4957c2ee83e
# 20   f042fdf7-ad3e-4f99-b3d4-1cf8c65a68ab
# ...

# %% [markdown]
# ### WER Comparison

# %%
print ('Avg WER Comparision')
print(f'Indic_conformer WER: {df["slang_indic_conformer_wer"].mean()}')
print(f'Google Speech WER: {df["slang_google_speech_wer"].mean()}')
# Out:
# Avg WER Comparision
# Indic_conformer WER: 0.35683261597931903
# Google Speech WER: 0.4528792217033441
